# %% [markdown]
# <a href="https://colab.research.google.com/github/KeertanPatro/Unsupervised/blob/main/Netflix_Movies_and_TV_shows_clustering_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - Unsupervised
# ##### **Contribution**    - Individual
# ##### **Team Member 1 -** Konapala Sai Keertan Patro

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Write the summary here within 500-600 words.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Write Problem Statement Here.**

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 15 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]
#
#
#
#
#
# 6. You may add more ml algorithms for model creation. Make sure for each and every algorithm, the following format should be answered.
#
#
# *   Explain the ML Model used and it's performance using Evaluation metric Score Chart.
#
#
# *   Cross- Validation & Hyperparameter Tuning
#
# *   Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.
#
# *   Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries

# data wrangling
import pandas as pd
import numpy as np

# data visualization
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gpd
from wordcloud import WordCloud, STOPWORDS

# text preprocessing
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

# %%
plt.style.use('ggplot')

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Netflix_clustering_unsupervised/NETFLIX MOVIES AND TV SHOWS CLUSTERING.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year rating   duration  \
# 0    August 14, 2020          2020  TV-MA  4 Seasons
# 1  December 23, 2016          2016  TV-MA     93 min
# 2  December 20, 2018          2011      R     78 min
# 3  November 16, 2017          2009  PG-13     80 min
# 4    January 1, 2020          2008  PG-13    123 min
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
# 3  Action & Adventure, Independent Movies, Sci-Fi...
# 4                                             Dramas
#
#                                          description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...
# 2  When an army recruit is found dead, his fellow...
# 3  In a postapocalyptic world, rag-doll robots hi...
# 4  A brilliant group of students become card-coun...

# %%
df.tail()
# Out:
#      show_id     type                                    title     director  \
# 7782   s7783    Movie                                     Zozo  Josef Fares
# 7783   s7784    Movie                                   Zubaan  Mozez Singh
# 7784   s7785    Movie                        Zulu Man in Japan          NaN
# 7785   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    cast  \
# 7782  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7783  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7784                                            Nasty C
# 7785                         Adriano Zumbo, Rachel Khoo
# 7786                                                NaN
#
#                                                 country          date_added  \
# 7782  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# 7783                                              India       March 2, 2019
# 7784                                                NaN  September 25, 2020
# 7785                                          Australia    October 31, 2020
# 7786              United Kingdom, Canada, United States       March 1, 2020
#
#       release_year rating  duration  \
# 7782          2005  TV-MA    99 min
# 7783          2015  TV-14   111 min
# 7784          2019  TV-MA    44 min
# 7785          2019  TV-PG  1 Season
# 7786          2019  TV-MA    90 min
#
#                                               listed_in  \
# 7782                       Dramas, International Movies
# 7783     Dramas, International Movies, Music & Musicals
# 7784  Documentaries, International Movies, Music & M...
# 7785                 International TV Shows, Reality TV
# 7786                    Documentaries, Music & Musicals
#
#                                             description
# 7782  When Lebanon's Civil War deprives Zozo of his ...
# 7783  A scrappy but poor boy worms his way into a ty...
# 7784  In this documentary, South African rapper Nast...
# 7785  Dessert wizard Adriano Zumbo looks for the nex...
# 7786  This documentary delves into the mystique behi...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape
# Out:
# (7787, 12)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7787 entries, 0 to 7786
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       7787 non-null   object
#  1   type          7787 non-null   object
#  2   title         7787 non-null   object
#  3   director      5398 non-null   object
#  4   cast          7069 non-null   object
#  5   country       7280 non-null   object
#  6   date_added    7777 non-null   object
#  7   release_year  7787 non-null   int64
#  8   rating        7780 non-null   object
#  9   duration      7787 non-null   object
#  10  listed_in     7787 non-null   object
#  11  description   7787 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 730.2+ KB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2389
# cast             718
# country          507
# date_added        10
# release_year       0
# rating             7
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %%
# Visualizing the missing values
sns.heatmap(df.isna().transpose())
# Out:
# <Axes: >

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# *  There are 7787 observations and 12 columns.
# * There are some missing values found in column director,cast and country.
# * There are no duplicate values present in thid dataset.
# * The datatype of the most features are object.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
# Dataset Describe
df.describe(include='object')
# Out:
#        show_id   type title                director                cast  \
# count     7787   7787  7787                    5398                7069
# unique    7787      2  7787                    4049                6831
# top         s1  Movie    3%  Raúl Campos, Jan Suter  David Attenborough
# freq         1   5377     1                      18                  18
#
#               country       date_added rating  duration      listed_in  \
# count            7280             7777   7780      7787           7787
# unique            681             1565     14       216            492
# top     United States  January 1, 2020  TV-MA  1 Season  Documentaries
# freq             2555              118   2863      1608            334
#
#                                               description
# count                                                7787
# unique                                               7769
# top     Multiple women report their husbands as missin...
# freq                                                    3

# %% [markdown]
# ### Variables Description

# %% [markdown]
# **Show_id:** unique id foe each movie.
# **type:**    identifier(movie/TV show).
# **Title:**   Title of the movie/show.
# **director:**  Director of the show.
# **cast:**  actors involved.
# **country:**  Country of the  production.
# **date_added:** date it was added on netflix.
# **Year_release:**  Actual release year of the show.
# **ratings:**  TV ratings of the show.
# **duration:** Total duration in minutes or number of seasons.
# **listed_in:** Genre of the Movie/Show.
# Description: A brief description of the movie/show.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
df.nunique()
# Out:
# show_id         7787
# type               2
# title           7787
# director        4049
# cast            6831
# country          681
# date_added      1565
# release_year      73
# rating            14
# duration         216
# listed_in        492
# description     7769
# dtype: int64

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# converting date_added column to date datatype
df['date_added']=pd.to_datetime(df['date_added'])

# %%
# adding month and year feature to our data
df['month_added']=df['date_added'].dt.month_name()
df['year_added']=df['date_added'].dt.year.convert_dtypes()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7787 entries, 0 to 7786
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       7787 non-null   object
#  1   type          7787 non-null   object
#  2   title         7787 non-null   object
#  3   director      5398 non-null   object
#  4   cast          7069 non-null   object
#  5   country       7280 non-null   object
#  6   date_added    7777 non-null   datetime64[ns]
#  7   release_year  7787 non-null   int64
#  8   rating        7780 non-null   object
#  9   duration      7787 non-null   object
#  10  listed_in     7787 non-null   object
#  11  description   7787 non-null   object
#  12  month_added   7777 non-null   object
#  13  year_added    7777 non-null   Int64
# dtypes: Int64(1), datetime64[ns](1), int64(1), object(11)
# memory usage: 859.4+ KB

# %%
df.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   date_added  release_year rating   duration  \
# 0 2020-08-14          2020  TV-MA  4 Seasons
# 1 2016-12-23          2016  TV-MA     93 min
# 2 2018-12-20          2011      R     78 min
# 3 2017-11-16          2009  PG-13     80 min
# 4 2020-01-01          2008  PG-13    123 min
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
# 3  Action & Adventure, Independent Movies, Sci-Fi...
# 4                                             Dramas
#
#                                          description month_added  year_added
# 0  In a future where the elite inhabit an island ...      August        2020
# 1  After a devastating earthquake hits Mexico Cit...    December        2016
# 2  When an army recruit is found dead, his fellow...    December        2018
# 3  In a postapocalyptic world, rag-doll robots hi...    November        2017
# 4  A brilliant group of students become card-coun...     January        2020

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# I have changed date_added column into datetime format and extracted month and year from the feature.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Exploring motion picture categories.

# %%
df['type'].value_counts()
# Out:
# Movie      5377
# TV Show    2410
# Name: type, dtype: int64

# %%
# different types of items
fig,ax=plt.subplots(1,2,figsize=(9,5))
sns.countplot(x='type',data=df,ax=ax[0])
ax[1].pie(df['type'].value_counts(),labels=['Movie','TV Show'],autopct='%.1f%%')
fig.suptitle('Distribution of Motion Picture categories')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We wanted to see the distribution of movies and TV shows in the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We see that more movies than TV shows in our dataset, around 69% of the items are movies while 31% items are TV shows.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Top Directors

# %%
tv_directors=df[df['type']=='TV Show']['director'].value_counts(ascending=False)
movie_directors=df[df['type']=='Movie']['director'].value_counts(ascending=False)

# %%
# visualizing top 10 directors
fig,ax=plt.subplots(1,2,figsize=(12,5))
tv_directors[:10].plot(kind='barh',ax=ax[0])
ax[0].set_title("Top 10 TV show directors")
movie_directors[:10].plot(kind='barh',ax=ax[1])
plt.tight_layout()
ax[1].set_title("Top 10 Movie directors")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We wanted to look into top 10 directors of both movies and TV show

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Top Casts

# %%
# Chart - 3 visualization code
df['cast']
# Out:
# 0       João Miguel, Bianca Comparato, Michel Gomes, R...
# 1       Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2       Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3       Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4       Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
#                               ...
# 7782    Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7783    Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7784                                              Nasty C
# 7785                           Adriano Zumbo, Rachel Khoo
# 7786                                                  NaN
# Name: cast, Length: 7787, dtype: object

# %%
# separating tv cast names
tv_cast_names=df[df['type']=='TV Show']['cast'].str.split(', ').explode().value_counts()

# separating movie cast names
movie_cast_names=df[df['type']=='Movie']['cast'].str.split(', ').explode().value_counts()

# %%
# Visualizing top casts
fig,ax=plt.subplots(1,2,figsize=(12,5))
tv_cast_names[:10].plot(kind='barh',ax=ax[0])
ax[0].set_title("Top 10 TV show artists")
movie_cast_names[:10].plot(kind='barh',ax=ax[1])
plt.tight_layout()
ax[1].set_title("Top 10 Movie artists")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We wanted to look into top artists in both tv as well as movies

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Distribution of Pictures based on country

# %%
country_counts=df['country'].str.split(", ").explode()
country_counts=country_counts.value_counts()
country_counts.rename(index={'United States':'United States of America'},inplace=True)

# %%
# top 5 countries
country_counts[:5].plot(kind='bar')
plt.title("Top 5 countries having highest pictures")
plt.ylabel('Counts')
plt.show()

# %%
# Visualizing the distribution using world map
worldmap=gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
merged_data=pd.merge(worldmap,country_counts,left_on='name',right_index=True,how='left')
merged_data.rename(columns={'country':'counts'},inplace=True)
merged_data['counts']=merged_data['counts'].fillna(0)

# plotting
fig, ax = plt.subplots(figsize=(15, 10))
merged_data.plot(column='counts', linewidth=0.8,edgecolor='black',ax=ax,legend=True,cmap='gist_earth_r')
plt.title('Distribution of pictures based on countries')
plt.show()
# Out:
# <ipython-input-28-0dda1c10eac0>:2: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   worldmap=gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We wanted to visualize distribution of movies/tv shows across various countries.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most of the pictures in this dataset are american, there are few Indian pictures followed by England, Canada and France.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Analyzing Titles of the Picture

# %%
df['title'].tail()
# Out:
# 7782                                       Zozo
# 7783                                     Zubaan
# 7784                          Zulu Man in Japan
# 7785                      Zumbo's Just Desserts
# 7786    ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
# Name: title, dtype: object

# %%
text=' '.join(title for title in df['title'] )
word_cloud=WordCloud(stopwords=STOPWORDS, background_color='white').generate(text)

# %%
# visualizing most frequent words
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(word_cloud,interpolation='bilinear')
plt.axis("off")
plt.title("Most frequent words used")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We wanted to see what are the frequent words used in the Movie/TV Show title for this dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above plot we find that the most frequent words used in the dataset are Love, World, Christmas, Man etc. So we can expect that movies are based on Love, Christmas and so on.

# %%
df.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   date_added  release_year rating   duration  \
# 0 2020-08-14          2020  TV-MA  4 Seasons
# 1 2016-12-23          2016  TV-MA     93 min
# 2 2018-12-20          2011      R     78 min
# 3 2017-11-16          2009  PG-13     80 min
# 4 2020-01-01          2008  PG-13    123 min
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
# 3  Action & Adventure, Independent Movies, Sci-Fi...
# 4                                             Dramas
#
#                                          description month_added  year_added
# 0  In a future where the elite inhabit an island ...      August        2020
# 1  After a devastating earthquake hits Mexico Cit...    December        2016
# 2  When an army recruit is found dead, his fellow...    December        2018
# 3  In a postapocalyptic world, rag-doll robots hi...    November        2017
# 4  A brilliant group of students become card-coun...     January        2020

# %% [markdown]
# #### Release year of the Picture

# %%
# Distribution of pictures based on release year
fig, ax=plt.subplots(1,2,figsize=(12,5))
sns.histplot(df['release_year'],kde=True,ax=ax[0])
ax[0].set_title("Distribution of pictures")
sns.countplot(x='release_year',hue='type',order=df['release_year'].value_counts()[:10].index,data=df,ax=ax[1])
ax[1].set_title("Movie/TV shows released in top 10 years ")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We wanted to look into which all years movies does this dataset contains.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We find that this dataset primary contains movies which are released in the year 2018, 2017.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# ###Ratings

# %%
# Distribution based on ratings

fig, ax=plt.subplots(1,2,figsize=(12,5))
sns.countplot(x='rating',data=df,ax=ax[0],order=df['rating'].value_counts().index[:10])
sns.countplot(x='rating',hue='type',order=df['rating'].value_counts().index[:10],data=df,ax=ax[1])
fig.suptitle("Distribution based on ratings")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We wanted to see the rating distribution to our movies/tv shows in the dataset to understand for which audience this dataset belongs to.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above plot we see that most of the pictures have ratings like TV-MA, TV-14, TV-PG, which suggest that these shows are for mature audience, and very few picture are meant for the kids.

# %% [markdown]
# #### Movies/ TV show based on Generes.

# %%
mov_genres=df.loc[df['type']=='Movie']['listed_in'].str.split(", ").explode()

tv_genres=df.loc[df['type']=='TV Show']['listed_in'].str.split(", ").explode()
tv_genres
# Out:
# 0             International TV Shows
# 0                          TV Dramas
# 0                TV Sci-Fi & Fantasy
# 5             International TV Shows
# 5                          TV Dramas
#                     ...
# 7779          International TV Shows
# 7779       Spanish-Language TV Shows
# 7779    Stand-Up Comedy & Talk Shows
# 7785          International TV Shows
# 7785                      Reality TV
# Name: listed_in, Length: 5525, dtype: object

# %%
# visualizing top genres for movie and tv shows
fig,ax=plt.subplots(1,2,figsize=(12,5))
sns.countplot(y=mov_genres,order=mov_genres.value_counts().index[:10],palette='Spectral_r',ax=ax[0])
ax[0].set_title("Top 10 Movie Genres")
ax[0].set_ylabel("")
sns.countplot(y=tv_genres,order=tv_genres.value_counts().index[:10],palette='Spectral_r',ax=ax[1])
ax[1].set_title("Top 10 TV genres")
ax[1].set_ylabel("")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We wanted to see what are the top genres for Movies and TV shows that people prefer.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above chart we find that people in genral like international movies and shows followed by drama and comedy.

# %% [markdown]
# #### Analyzing description

# %%
text=' '.join(words for words in df['description'] )
word_cloud=WordCloud(stopwords=STOPWORDS, background_color='white').generate(text)

# %%
# visualizing most frequent words

plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(word_cloud,interpolation='bilinear')
plt.axis("off")
plt.title("Most frequent words used")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We wanted to see the most frequent used in the decription of a movie or tv show.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The most frequent words are family, friend, life, love, world  etc.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ## ***5. Hypothesis Testing***

# %% [markdown]
# ### Based on your chart experiments, define three hypothetical statements from the dataset. In the next three questions, perform hypothesis testing to obtain final conclusion about the statements through your code and statistical testing.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### Hypothetical Statement - 1

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### Hypothetical Statement - 2

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### Hypothetical Statement - 3

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***6. Feature Engineering & Data Pre-processing***

# %%
# creating copy
netflix_df=df.copy()

# %% [markdown]
# ### 1. Handling Missing Values

# %%
# Handling Missing Values & Missing Value Imputation
netflix_df.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2389
# cast             718
# country          507
# date_added        10
# release_year       0
# rating             7
# duration           0
# listed_in          0
# description        0
# month_added       10
# year_added        10
# dtype: int64

# %% [markdown]
# We see lot of missing values in column director, cast, country.

# %%
# handling missing values in director, cast, country
netflix_df[['director','cast','country']]=netflix_df[['director','cast','country']].fillna('')

# dropping missing values in date_added release_year
netflix_df=netflix_df.dropna(subset=['date_added','rating'])

# %%
netflix_df['rating']
# Out:
# 0       TV-MA
# 1       TV-MA
# 2           R
# 3       PG-13
# 4       PG-13
#         ...
# 7782    TV-MA
# 7783    TV-14
# 7784    TV-MA
# 7785    TV-PG
# 7786    TV-MA
# Name: rating, Length: 7770, dtype: object

# %%
netflix_df.isna().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# month_added     0
# year_added      0
# dtype: int64

# %% [markdown]
# #### What all missing value imputation techniques have you used and why did you use those techniques?

# %% [markdown]
# We have replaced the missing value in director, cast, country as unknown and we have dropped the missing values in date_added and ratings.

# %% [markdown]
# ### 2. Handling Outliers

# %%
# let us look at our numerical columns
num_col=df.describe().columns
num_col
# Out:
# Index(['release_year', 'year_added'], dtype='object')

# %%
df['year_added']
# Out:
# 0       2020
# 1       2016
# 2       2018
# 3       2017
# 4       2020
#         ...
# 7782    2020
# 7783    2019
# 7784    2020
# 7785    2020
# 7786    2020
# Name: year_added, Length: 7787, dtype: Int64

# %%
# plotting these two numeric variables
fig,ax=plt.subplots(1,2,figsize=(12,5))
sns.histplot(df["release_year"],kde=True,ax=ax[0])
sns.boxplot(y=df['release_year'],ax=ax[1])
fig.suptitle("Outliers in numeric columns")
# Out:
# Text(0.5, 0.98, 'Outliers in numeric columns')

# %% [markdown]
# ##### What all outlier treatment techniques have you used and why did you use those techniques?

# %% [markdown]
# Since there are only two numeric columns, rest are text data, and we won't need the numeric data for our clustering analysis, so we let the outliers be as it is.

# %% [markdown]
# ### 3. Categorical Encoding

# %%
# Encode your categorical columns
ratings = {'TV-MA':'Adults',
              'R':'Adults',
              'PG-13':'Teens',
              'TV-14':'Young Adults',
              'TV-PG':'Older Kids',
              'NR':'Adults',
              'TV-G':'Kids',
              'TV-Y':'Kids',
              'TV-Y7':'Older Kids',
              'PG':'Older Kids',
              'G':'Kids',
              'NC-17':'Adults',
              'TV-Y7-FV':'Older Kids',
              'UR':'Adults'}
netflix_df['rating']=netflix_df['rating'].map(ratings)

# %% [markdown]
# #### What all categorical encoding techniques have you used & why did you use those techniques?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 4. Textual Data Preprocessing
# (It's mandatory for textual dataset i.e., NLP, Sentiment Analysis, Text Clustering etc.)

# %%
netflix_df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description',
#        'month_added', 'year_added'],
#       dtype='object')

# %%
netflix_df['description'].head()
# Out:
# 0    In a future where the elite inhabit an island ...
# 1    After a devastating earthquake hits Mexico Cit...
# 2    When an army recruit is found dead, his fellow...
# 3    In a postapocalyptic world, rag-doll robots hi...
# 4    A brilliant group of students become card-coun...
# Name: description, dtype: object

# %%
netflix_df['director'].head()
# Out:
# 0
# 1    Jorge Michel Grau
# 2         Gilbert Chan
# 3          Shane Acker
# 4       Robert Luketic
# Name: director, dtype: object

# %%
def director_merge(name):
  merge_name=[]
  for word in name.split(" "):
    merge_name.append(word)
  merge_name=''.join(merge_name)
  return merge_name

netflix_df['director']=netflix_df['director'].apply(director_merge)

# %%
netflix_df['cast'].head()
# Out:
# 0    João Miguel, Bianca Comparato, Michel Gomes, R...
# 1    Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2    Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3    Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4    Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# Name: cast, dtype: object

# %%
def merging_names(text):
  new_text=[]
  for name in text.split(', '):
    new_name=name.replace(" ","")
    new_text.append(new_name)
  new_text=", ".join(new_text)
  return new_text
merging_names(netflix_df['cast'][0])
netflix_df['cast']=netflix_df['cast'].apply(merging_names)
netflix_df['cast'].head()
# Out:
# 0    JoãoMiguel, BiancaComparato, MichelGomes, Rodo...
# 1    DemiánBichir, HéctorBonilla, OscarSerrano, Aza...
# 2    TeddChan, StellaChung, HenleyHii, LawrenceKoh,...
# 3    ElijahWood, JohnC.Reilly, JenniferConnelly, Ch...
# 4    JimSturgess, KevinSpacey, KateBosworth, AaronY...
# Name: cast, dtype: object

# %%
netflix_df['rating']
# Out:
# 0             Adults
# 1             Adults
# 2             Adults
# 3              Teens
# 4              Teens
#             ...
# 7782          Adults
# 7783    Young Adults
# 7784          Adults
# 7785      Older Kids
# 7786          Adults
# Name: rating, Length: 7770, dtype: object

# %% [markdown]
# #### 1. Expand Contraction

# %%
# Expand Contraction
netflix_df['combined_text']=netflix_df['director']+' '+ netflix_df['cast']+ " "+ netflix_df['rating']+ ' ' \
                                 +netflix_df['listed_in']+ ' ' + netflix_df['description']

# %%
netflix_df['combined_text'][0]
# Out:
# ' JoãoMiguel, BiancaComparato, MichelGomes, RodolfoValente, VanezaOliveira, RafaelLozano, VivianePorto, MelFronckowiak, SergioMamberti, ZezéMotta, CelsoFrateschi Adults International TV Shows, TV Dramas, TV Sci-Fi & Fantasy In a future where the elite inhabit an island paradise far from the crowded slums, you get one chance to join the 3% saved from squalor.'

# %% [markdown]
# #### 2. Lower Casing

# %%
# Lower Casing
def lower_casing(text):
  text=text.lower()
  return text
netflix_df['combined_text']=netflix_df['combined_text'].apply(lower_casing)

# %% [markdown]
# #### 3. Removing Punctuations

# %%
# Remove Punctuations
def remove_punctuations(text):
  text=re.sub(r'[^\w\s]','',text)
  return text
netflix_df['combined_text']=netflix_df['combined_text'].apply(remove_punctuations)

# %% [markdown]
# #### 4. Removing URLs & Removing words and digits contain digits.

# %%
# Remove URLs & Remove words and digits contain digits
def remove_url(text):
  text=re.sub(r'https?\S+|www\S+','',text) # removing urls
  text=re.sub(r'\w*\d+\w*','',text) # removing words which contain digits
  return text
netflix_df['combined_text']=netflix_df['combined_text'].apply(remove_url)

# %%
netflix_df['combined_text'][0]
# Out:
# ' joãomiguel biancacomparato michelgomes rodolfovalente vanezaoliveira rafaellozano vivianeporto melfronckowiak sergiomamberti zezémotta celsofrateschi adults international tv shows tv dramas tv scifi  fantasy in a future where the elite inhabit an island paradise far from the crowded slums you get one chance to join the  saved from squalor'

# %% [markdown]
# #### 5. Removing Stopwords & Removing White spaces

# %%
nltk.download('stopwords')
sw=stopwords.words('english')
np.array(sw)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# array(['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you',
#        "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself',
#        'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her',
#        'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them',
#        'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom',
#        'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are',
#        'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had',
#        'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and',
#        'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at',
#        'by', 'for', 'with', 'about', 'against', 'between', 'into',
#        'through', 'during', 'before', 'after', 'above', 'below', 'to',
#        'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under',
#        'again', 'further', 'then', 'once', 'here', 'there', 'when',
#        'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more',
#        'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own',
#        'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will',
#        'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll',
#        'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn',
#        "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't",
#        'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma',
#        'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't",
#        'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't",
#        'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"],
#       dtype='<U10')

# %%
# Remove Stopwords
def remove_stopwords(text):
  new_text=[words for words in text.split() if words not in sw]
  new_text=' '.join(new_text)
  return new_text
netflix_df['combined_text']= netflix_df['combined_text'].apply(remove_stopwords)
netflix_df['combined_text'][0]
# Out:
# 'joãomiguel biancacomparato michelgomes rodolfovalente vanezaoliveira rafaellozano vivianeporto melfronckowiak sergiomamberti zezémotta celsofrateschi adults international tv shows tv dramas tv scifi fantasy future elite inhabit island paradise far crowded slums get one chance join saved squalor'

# %% [markdown]
# #### 6. Lemmatization

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
def lemmatizer(text):
  lemmatizer=WordNetLemmatizer()
  lemmas=[]
  for word in text.split():
    lemma=lemmatizer.lemmatize(word,pos='v')
    lemmas.append(lemma)
  new_text=' '.join(lemmas)
  return new_text
netflix_df['combined_text']=netflix_df['combined_text'].apply(lemmatizer)

# %%
netflix_df['combined_text'][0]
# Out:
# 'joãomiguel biancacomparato michelgomes rodolfovalente vanezaoliveira rafaellozano vivianeporto melfronckowiak sergiomamberti zezémotta celsofrateschi adults international tv show tv dramas tv scifi fantasy future elite inhabit island paradise far crowd slum get one chance join save squalor'

# %% [markdown]
# #### 7. Tokenization

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
tokenized_data=netflix_df['combined_text'].copy()

# %%
# Tokenization
tokenized_data=tokenized_data.apply(word_tokenize)
tokenized_data[45]
# Out:
# ['alicanyücesoy',
#  'melisasözen',
#  'musauzunlar',
#  'serkanercan',
#  'özkanuğur',
#  'ülküduru',
#  'tansubiçer',
#  'nadirsarıbacak',
#  'sermetyeşil',
#  'ayhankavas',
#  'adults',
#  'crime',
#  'tv',
#  'show',
#  'international',
#  'tv',
#  'show',
#  'tv',
#  'dramas',
#  'orphan',
#  'subject',
#  'test',
#  'give',
#  'superpowers',
#  'rescue',
#  'raise',
#  'istanbuls',
#  'streets',
#  'fall',
#  'reporter',
#  'link',
#  'past']

# %%
tokenized_data[0]
# Out:
# ['joãomiguel',
#  'biancacomparato',
#  'michelgomes',
#  'rodolfovalente',
#  'vanezaoliveira',
#  'rafaellozano',
#  'vivianeporto',
#  'melfronckowiak',
#  'sergiomamberti',
#  'zezémotta',
#  'celsofrateschi',
#  'adults',
#  'international',
#  'tv',
#  'show',
#  'tv',
#  'dramas',
#  'tv',
#  'scifi',
#  'fantasy',
#  'future',
#  'elite',
#  'inhabit',
#  'island',
#  'paradise',
#  'far',
#  'crowd',
#  'slum',
#  'get',
#  'one',
#  'chance',
#  'join',
#  'save',
#  'squalor']

# %% [markdown]
# #### 8. Text Vectorization

# %%
# TF-IDF
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(lowercase=False,max_features=10000)
X = vectorizer.fit_transform(netflix_df['combined_text'])

# %%
X=X.toarray()

# %%
vectorizer.get_feature_names_out()[:30]
# Out:
# array(['aakashdabhade', 'aamirbashir', 'aamirkhan', 'aaron',
#        'aaronabrams', 'aaronburns', 'aarondouglas', 'aaroneckhart',
#        'aaronjeffery', 'aaronpaul', 'aarontaylorjohnson', 'aaronyan',
#        'aaronyoo', 'aashishchaudhary', 'aasifmandvi', 'abandon',
#        'abbasalibhaiburmawallamastanalibhaiburmawalla', 'abbey',
#        'abbiecornish', 'abbydonnelly', 'abbytrott', 'abdalahmishrif',
#        'abdelaziznmila', 'abdelilahwahbi', 'abduct', 'abduction',
#        'abhaydeol', 'abhimanyusingh', 'abhishekbachchan',
#        'abigailbreslin'], dtype=object)

# %% [markdown]
# ##### Which text vectorization technique have you used and why?

# %% [markdown]
# Here we have used TF-IDF vectorization technique, it is the best technique as it gives more importance to less frequent words, and less importance to high frequent words.

# %% [markdown]
# ### 4. Feature Manipulation & Selection

# %% [markdown]
# #### 1. Feature Manipulation

# %%
# Manipulate Features to minimize feature correlation and create new features

# %% [markdown]
# #### 2. Feature Selection

# %%
# Select your features wisely to avoid overfitting

# %% [markdown]
# ##### What all feature selection methods have you used  and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Which all features you found important and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 5. Data Transformation

# %% [markdown]
# #### Do you think that your data needs to be transformed? If yes, which transformation have you used. Explain Why?

# %%
# Transform Your data

# %% [markdown]
# ### 6. Data Scaling

# %%
# Scaling your data

# %% [markdown]
# ##### Which method have you used to scale you data and why?

# %% [markdown]
# ### 7. Dimesionality Reduction

# %% [markdown]
# ##### Do you think that dimensionality reduction is needed? Explain Why?

# %% [markdown]
# Dimension reduction is needed as there are more than 20000 features and when we do clustering analysis of this many dimensions our program would crash.

# %%
from sklearn.decomposition import PCA

# %%
# DImensionality Reduction (If needed)

pca=PCA()
pca.fit(X)
print(pca.explained_variance_ratio_)
# Out:
# [1.47507829e-02 6.26262828e-03 5.68458535e-03 ... 7.45164887e-35
#  6.87506576e-35 6.43302622e-35]

# %%
netflix_df['rating'].head()
# Out:
# 0    Adults
# 1    Adults
# 2    Adults
# 3     Teens
# 4     Teens
# Name: rating, dtype: object

# %%
# plotting to see explained variance
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.axvline(x=3000,color='g',linestyle='--')
plt.xlabel("Components")
plt.ylabel("Cummulative explained variance")
plt.title("Cummulative explained variance using PCA")
plt.show()

# %% [markdown]
# ##### Which dimensionality reduction technique have you used and why? (If dimensionality reduction done on dataset.)

# %% [markdown]
# We have used PCA to reduce the dimension of the dataset, from the above plot we find that about 3000 components could explain about 80% of the variance.

# %%
# using pca to reduce dimensions
pca=PCA(n_components=3000, random_state=0)
X_pca=pca.fit_transform(X)

# %%
netflix_df['rating'].head(3)
# Out:
# 0    Adults
# 1    Adults
# 2    Adults
# Name: rating, dtype: object

# %%
X_pca.shape
# Out:
# (7770, 3000)

# %% [markdown]
# ### 8. Data Splitting

# %%
# Split your data to train and test. Choose Splitting ratio wisely.

# %% [markdown]
# ##### What data splitting ratio have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 9. Handling Imbalanced Dataset

# %% [markdown]
# ##### Do you think the dataset is imbalanced? Explain Why.

# %% [markdown]
# Answer Here.

# %%
# Handling Imbalanced Dataset (If needed)

# %% [markdown]
# ##### What technique did you use to handle the imbalance dataset and why? (If needed to be balanced)

# %% [markdown]
# Answer Here.

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## ***7. ML Model Implementation***

# %% [markdown]
# ## **K Means**

# %%
from sklearn.cluster import KMeans

# %%
# Elbow method to determine the best value of n_clusters

sse=[]
for k in range(1,16):
  kmeans=KMeans(n_clusters=k,init='k-means++',random_state=0)
  kmeans.fit(X_pca)
  sse.append(kmeans.inertia_)

# %%
# plotting sse to find optimal k value
plt.plot(range(1,16),sse)
plt.xlabel('number of clusters')
plt.ylabel('sse')
plt.title("Elbow method-Kmeans clustering")
plt.show()

# %% [markdown]
# From the above plot we see that as number of clusters increases the sse value decreases, it is difficult to point out the elbow from the above curve. We need a better method to find out the best value of number of clusters.

# %%
netflix_df['rating'].head(3)
# Out:
# 0    Adults
# 1    Adults
# 2    Adults
# Name: rating, dtype: object

# %%
from sklearn.metrics import silhouette_score

# %%
# silhoutte method to find best value of k
sil_score=[]
for k in range(2,16):
  kmeans=KMeans(n_clusters=k,init='k-means++',random_state=0)
  kmeans.fit(X_pca)
  label=kmeans.labels_
  sil_score.append(silhouette_score(X_pca, label))

# %%
# plotting silhouette scores for different clusters
plt.plot(range(2,16),sil_score)
plt.xlabel('number of clusters')
plt.ylabel('silhouette scores')
plt.title('Silhouette method to find best k')
plt.show()

# %% [markdown]
# The number of clusters is determined for which silhouette score is maximum, from the above plot we find that the silhouette score is maximum for k=6, hence the number of clusters which we should choose for this problem is 6.

# %%
# clustering the data into 6 clusters
kmeans = KMeans(n_clusters=6, init='k-means++', random_state=0)
kmeans.fit(X_pca)
# Out:
# KMeans(n_clusters=6, random_state=0)

# %%
# evaluation metric
kmeans_sse = kmeans.inertia_
kmeans_silhouette_score = silhouette_score(X_pca, kmeans.labels_)

# %%
print("sse for 6 clusters is:",kmeans_sse)
print("silhouette_score for 6 clusters is",kmeans_silhouette_score)
# Out:
# sse for 6 clusters is: 6213.976191049532
# silhouette_score for 6 clusters is 0.014467557210595037

# %%
netflix_df['rating'].value_counts()
# Out:
# Adults          3617
# Young Adults    1928
# Older Kids      1327
# Kids             512
# Teens            386
# Name: rating, dtype: int64

# %%
# labelling the dataset
kmeans.labels_
netflix_df['clustering_label']=kmeans.labels_
netflix_df.sample(5)
# Out:
#      show_id     type                          title       director  \
# 1049   s1050  TV Show                    Borderliner
# 1332   s1333  TV Show               Children of Adam
# 4036   s4037    Movie                        Menorca    JohnBarnard
# 7136   s7137    Movie  Tom Papa: You're Doing Great!  GregoryJacobs
# 605     s606    Movie                     Asura Guru    A.Raajdheep
#
#                                                    cast  \
# 1049  TobiasSantelmann, EllenDorritPetersen, Benjami...
# 1332  MaguyBouGhosn, DaniellaRahme, MaximKhalil, Qay...
# 4036  TammyGillis, SheilaCampbell, TaliaPura, Doroth...
# 7136                                            TomPapa
# 605   VikramPrabhu, Subbaraju, MahimaNambiar, YogiBa...
#
#                       country date_added  release_year        rating  \
# 1049  Norway, Germany, Sweden 2018-03-06          2017        Adults
# 1332                  Lebanon 2020-12-12          2020  Young Adults
# 4036            Canada, Spain 2017-08-27          2016        Adults
# 7136            United States 2020-02-04          2020  Young Adults
# 605                     India 2020-06-13          2020  Young Adults
#
#       duration                                          listed_in  \
# 1049  1 Season  Crime TV Shows, International TV Shows, TV Dramas
# 1332  1 Season    International TV Shows, TV Dramas, TV Thrillers
# 4036    81 min                         Dramas, Independent Movies
# 7136    60 min                                    Stand-Up Comedy
# 605    117 min                       Dramas, International Movies
#
#                                             description month_added  \
# 1049  To protect his family, a police detective cove...       March
# 1332  Amid crime and corruption, the lives of two co...    December
# 4036  A hedonistic soccer mom takes a voyage of self...      August
# 7136  Comedian Tom Papa takes on body image issues, ...    February
# 605   For a tech-savvy thief, elaborate robberies an...        June
#
#       year_added                                      combined_text  \
# 1049        2018  tobiassantelmann ellendorritpetersen benjaminh...
# 1332        2020  maguyboughosn daniellarahme maximkhalil qayssh...
# 4036        2017  johnbarnard tammygillis sheilacampbell taliapu...
# 7136        2020  gregoryjacobs tompapa young adults standup com...
# 605         2020  araajdheep vikramprabhu subbaraju mahimanambia...
#
#       clustering_label
# 1049                 5
# 1332                 5
# 4036                 1
# 7136                 2
# 605                  1

# %%
# visualizing cluster distribution
bars=sns.countplot(x='clustering_label',data=netflix_df,hue='type')
plt.title("Number of movies and TV shows in each cluster")
for bar in bars.patches:
    yval = bar.get_height()
    plt.text(bar.get_x(), yval + 25, format(yval,'.0f'))

# %% [markdown]
# ### Analyzing key content present in clusters.

# %%
def kmeans_wordcloud(cluster_num):
  content_df=netflix_df[netflix_df['clustering_label']==cluster_num]['description']
  description_words=[]
  for text in content_df:
    for words in text.split():
      description_words.append(words)

  new_text=' '.join(description_words)
  word_cloud=WordCloud(stopwords=STOPWORDS,background_color='white').generate(new_text)
  plt.imshow(word_cloud, interpolation='bilinear')
  plt.axis("off")
  plt.show()

# %%
# key content in cluster 0
kmeans_wordcloud(0)

# %%
netflix_df[netflix_df['clustering_label']==0].sample(8)[['title','rating','listed_in']]
# Out:
#                                       title      rating  \
# 5844  Stretch Armstrong & the Flex Fighters  Older Kids
# 4115                            Miniforce X  Older Kids
# 2638                          Hart of Dixie  Older Kids
# 2367                                 Gemini  Older Kids
# 1646                    DC Super Hero Girls  Older Kids
# 3572                           Legend Quest  Older Kids
# 3575                    Legends of Strength  Older Kids
# 3559               LeapFrog: Letter Factory        Kids
#
#                       listed_in
# 5844                   Kids' TV
# 4115  Kids' TV, Korean TV Shows
# 2638     TV Comedies, TV Dramas
# 2367                     Dramas
# 1646                   Kids' TV
# 3572                   Kids' TV
# 3575                 Docuseries
# 3559   Children & Family Movies

# %%
# key content in cluster 1
kmeans_wordcloud(1)

# %%
netflix_df[netflix_df['clustering_label']==1].sample(8)[['title','rating','listed_in']]
# Out:
#                              title        rating  \
# 4218  Monty Python's Life of Brian        Adults
# 2796                     Honeytrap        Adults
# 4981                     Professor    Older Kids
# 3892                    Mama's Boy  Young Adults
# 3996                   May We Chat        Adults
# 5348                         Sakhi    Older Kids
# 6877          The Skin of the Wolf        Adults
# 5620        Sincerely Yours, Dhaka        Adults
#
#                                              listed_in
# 4218             Classic Movies, Comedies, Cult Movies
# 2796                        Dramas, Independent Movies
# 4981            Comedies, Dramas, International Movies
# 3892                    Comedies, International Movies
# 3996                      Dramas, International Movies
# 5348    Dramas, International Movies, Music & Musicals
# 6877  Dramas, Independent Movies, International Movies
# 5620              Comedies, Dramas, Independent Movies

# %%
# key content in cluster 2
kmeans_wordcloud(2)

# %%
netflix_df[netflix_df['clustering_label']==2].sample(8)[['title','rating','listed_in']]
# Out:
#                                          title        rating        listed_in
# 1601                   Daniel Sosa: Maleducado        Adults  Stand-Up Comedy
# 3991  Mau Nieto: Viviendo sobrio… desde el bar        Adults  Stand-Up Comedy
# 5507         Seth Rogen's Hilarity for Charity        Adults  Stand-Up Comedy
# 5359                Sam Kinison: Live in Vegas        Adults  Stand-Up Comedy
# 3169                Jim Gaffigan: Mr. Universe  Young Adults  Stand-Up Comedy
# 2601          Hannibal Buress: Comedy Camisado        Adults  Stand-Up Comedy
# 5117                                  Real Rob        Adults      TV Comedies
# 1684                         Def Comedy Jam 25        Adults  Stand-Up Comedy

# %%
# key content in cluster 3
kmeans_wordcloud(3)

# %%
netflix_df[netflix_df['clustering_label']==3].sample(8)[['title','rating','listed_in']]
# Out:
#                               title      rating  \
# 153                A Bridge Too Far  Older Kids
# 2553                       Guna 369      Adults
# 6162              The Bounty Hunter       Teens
# 3709                   London Heist      Adults
# 3278         Kabali (Hindi Version)      Adults
# 7212  Tremors 6: A Cold Day in Hell       Teens
# 2453                     God of War      Adults
# 7484                    Warrior Nun      Adults
#
#                                               listed_in
# 153          Action & Adventure, Classic Movies, Dramas
# 2553   Action & Adventure, Dramas, International Movies
# 6162      Action & Adventure, Comedies, Romantic Movies
# 3709                                 Action & Adventure
# 3278   Action & Adventure, Dramas, International Movies
# 7212        Action & Adventure, Comedies, Horror Movies
# 2453           Action & Adventure, International Movies
# 7484  TV Action & Adventure, TV Mysteries, TV Sci-Fi...

# %%
# key content in cluster 4
kmeans_wordcloud(4)

# %%
netflix_df[netflix_df['clustering_label']==4].sample(8)[['title','rating','listed_in']]
# Out:
#                                           title        rating  \
# 6793                                  The Queen        Adults
# 4549                                   Numbered    Older Kids
# 5450                    Searching for Sugar Man         Teens
# 5152  ReMastered: The Two Killings of Sam Cooke        Adults
# 6109                               The Bad Kids        Adults
# 2786                                  Home Game        Adults
# 5784                                   Star Men  Young Adults
# 5676                    Smash: Motorized Mayhem        Adults
#
#                                               listed_in
# 6793           Cult Movies, Documentaries, LGBTQ Movies
# 4549                Documentaries, International Movies
# 5450  Documentaries, International Movies, Music & M...
# 5152                    Documentaries, Music & Musicals
# 6109                                      Documentaries
# 2786                                         Docuseries
# 5784                                      Documentaries
# 5676                       Documentaries, Sports Movies

# %%
# key content in cluster 5
kmeans_wordcloud(5)

# %%
netflix_df[netflix_df['clustering_label']==5].sample(8)[['title','rating','listed_in']]
# Out:
#                    title        rating  \
# 7132         Tokyo Trial        Adults
# 3977   Masameer Classics  Young Adults
# 1473  Comedy High School  Young Adults
# 1954      El desconocido        Adults
# 2785  Home for Christmas        Adults
# 4143           Miss Rose        Adults
# 1100          Bridgerton        Adults
# 6412        The Governor  Young Adults
#
#                                               listed_in
# 7132                  International TV Shows, TV Dramas
# 3977                International TV Shows, TV Comedies
# 1473                International TV Shows, TV Comedies
# 1954  Crime TV Shows, International TV Shows, Spanis...
# 2785  International TV Shows, Romantic TV Shows, TV ...
# 4143  International TV Shows, Romantic TV Shows, TV ...
# 1100                       Romantic TV Shows, TV Dramas
# 6412                  International TV Shows, TV Dramas

# %% [markdown]
# ### **Hierarchial clustering**

# %%
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram, linkage

# %%
# plotting dendogram

Z = linkage(X_pca, method='ward')

# %%
plt.figure(figsize=(10, 6))
dendrogram(Z)
plt.xlabel('Data points')
plt.ylabel('Distance')
plt.axhline(y=4,color='green')
plt.title('Dendrogram')
plt.show()

# %% [markdown]
# number of clusters observed from the dendogram is 9.

# %%
# implementing agglomerative clustering
agg_model = AgglomerativeClustering(n_clusters=9, linkage='ward', affinity='euclidean')
agg_model.fit(X_pca)
# Out:
# AgglomerativeClustering(affinity='euclidean', n_clusters=9)

# %%
agg_model.labels_
netflix_df['hierc_cluster_label']=agg_model.labels_
netflix_df.sample(5)
# Out:
#      show_id     type              title     director  \
# 1311   s1312    Movie    Chennai Express  RohitShetty
# 1010   s1011  TV Show      Bo on the Go!
# 5001   s5002    Movie             Pulang  KabirBhatia
# 188     s189  TV Show  A House of Blocks
# 1442   s1443  TV Show      Cocaine Coast
#
#                                                    cast   country date_added  \
# 1311  ShahRukhKhan, DeepikaPadukone, NikitinDheer, S...     India 2018-08-31
# 1010       CatherineO'Connor, AndrewSabiston, JimFowler    Canada 2019-03-21
# 5001                 PuteriAishah, RemyIshak, AlvinWong  Malaysia 2018-10-08
# 188   EliShi, PhoebeLin, ChenWan-ting, FanChen-fei, ...    Taiwan 2017-09-01
# 1442  JavierRey, TristánUlloa, AntonioDurán'Morris',...     Spain 2018-08-03
#
#       release_year        rating  duration  \
# 1311          2013  Young Adults   135 min
# 1010          2007          Kids  1 Season
# 5001          2018  Young Adults   119 min
# 188           2017    Older Kids  1 Season
# 1442          2018        Adults  1 Season
#
#                                               listed_in  \
# 1311  Action & Adventure, Comedies, International Mo...
# 1010                                           Kids' TV
# 5001   Action & Adventure, Dramas, International Movies
# 188        International TV Shows, TV Dramas, TV Horror
# 1442  Crime TV Shows, International TV Shows, Spanis...
#
#                                             description month_added  \
# 1311  What could have been a sad journey turns joyfu...      August
# 1010  Staying at home doesn't mean sitting still for...       March
# 5001  Thom tells her grandson about his grandfather,...     October
# 188   Yijuan and her mentally ill sister Kaiqi strug...   September
# 1442  In 1980s Galicia, Spain, a young fisherman bec...      August
#
#       year_added                                      combined_text  \
# 1311        2018  rohitshetty shahrukhkhan deepikapadukone nikit...
# 1010        2019  catherineoconnor andrewsabiston jimfowler kid ...
# 5001        2018  kabirbhatia puteriaishah remyishak alvinwong y...
# 188         2017  elishi phoebelin chenwanting fanchenfei luhsue...
# 1442        2018  javierrey tristánulloa antonioduránmorris carl...
#
#       clustering_label  hierc_cluster_label
# 1311                 2                    2
# 1010                 2                    2
# 5001                 2                    2
# 188                  1                    1
# 1442                 7                    7

# %%
def hierachial_wordcloud(cluster_num):
  content_df=netflix_df[netflix_df['hierc_cluster_label']==cluster_num]['description']
  description_words=[]
  for text in content_df:
    for words in text.split():
      description_words.append(words)

  new_text=' '.join(description_words)
  word_cloud=WordCloud(stopwords=STOPWORDS,background_color='white').generate(new_text)
  plt.imshow(word_cloud, interpolation='bilinear')
  plt.axis("off")
  plt.show()

# %%
# key content in cluster 0
hierachial_wordcloud(0)

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 1 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 3. Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### ML Model - 3

# %%
# ML Model - 3 Implementation

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 3 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 1. Which Evaluation metrics did you consider for a positive business impact and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 2. Which ML model did you choose from the above created models as your final prediction model and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 3. Explain the model which you have used and the feature importance using any model explainability tool?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***8.*** ***Future Work (Optional)***

# %% [markdown]
# ### 1. Save the best performing ml model in a pickle file or joblib file format for deployment process.

# %%
# Save the File

# %% [markdown]
# ### 2. Again Load the saved model file and try to predict unseen data for a sanity check.

# %%
# Load the File and predict unseen data.

# %% [markdown]
# ### ***Congrats! Your model is successfully created and ready for deployment on a live server for a real user interaction !!!***

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your Machine Learning Capstone Project !!!***
